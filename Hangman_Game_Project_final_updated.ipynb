# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Description
# > ##### The Hangman program randomly selects a secret word from a list of secret words.
# > ##### The Game: Here, a random word (a fruit name) is picked up from our collection and the player gets limited chances to guess the fruit name correctly.
# > ##### When a letter in that word is guessed correctly, that letter position in the word is made visible in the output.
# > ##### In this way, all letters of the word are to be guessed before all the chances are over.
# > ##### For convenience, the number of chances equals the word length + 2.
# > ##### For example, word to be guessed is mango, then user gets 5 + 2 = 7 chances, as mango is a five letter word.
# > ##### Make game repeats until player ends the game.
# > ##### Bonus : Create a function that takes 3 parameters `Easy`, `Medium` and `Hard` where `Medium` has more difficult words to be guessed than `Easy` and so on.

# %%
fruits = [
    'Apple', 'Apricot', 'Avocado', 'Banana', 'Blackberry', 'Blueberry',
    'Boysenberry', 'Breadfruit', 'Cantaloupe', 'Cherimoya', 'Cherry',
    'Clementine', 'Coconut', 'Cranberry', 'Currant', 'Date', 'Dragonfruit',
    'Durian', 'Elderberry', 'Fig', 'Gooseberry', 'Grape', 'Grapefruit',
    'Guava', 'Honeydew', 'Jackfruit', 'Jambul', 'Jujube', 'Kiwi', 'Kumquat',
    'Lemon', 'LIME', 'Lychee', 'Mango', 'Mangosteen', 'Melon', 'Mulberry',
    'Nectarine', 'Orange', 'Papaya', 'Passionfruit', 'Peach', 'Pear',
    'Persimmon', 'Pineapple', 'Pitaya', 'Plum', 'Pomegranate', 'Pomelo',
    'Prune', 'Quince', 'Raspberry', 'Rambutan', 'Redcurrant', 'Starfruit',
    'Strawberry', 'Tamarind', 'Tangerine', 'Watermelon'
]

# %%
all_cars = [
    "Ford", "BMW", "Audi", "Jeep", "Kia", "Mini", "Fiat", "Volvo", "Saab",
    "Tesla", "Skoda", "Opel", "Dacia", "Lexus", "Nissan", "Honda", "Hyundai",
    "Mazda", "Chevy", "Buick", "Subaru", "Suzuki", "Toyota", "Ram", "Zotye",
    "Isuzu", "Acura", "BYD", "Tata", "JAC", "Haval", "MG", "Geely", "Chery",
    "Bugatti", "Peugeot", "Renault", "Daihatsu", "Infiniti", "Citroen",
    "Pontiac", "Scion", "Rivian", "Pagani", "Proton", "Saturn", "Genesis",
    "Seat", "Smart", "Holden", "Perodua", "Roewe", "Brilliance", "Fisker",
    "Koenigsegg", "Lucid", "Polestar", "VinFast", "Daewoo", "SsangYong"
]

# %%
fruits_easy = ['Apple','Date','Fig','Grape','Guava','Kiwi','Lemon','Lime','Mango','Melon','Peach','Pear','Plum']
fruits_medium = ['Apricot','Avocado','Banana','Cherry','Coconut','Currant','Durian','Honeydew','Jambul','Jujube','Kumquat','Lychee','Mulberry','Orange','Papaya','Pitaya','Pomelo','Quince','Rambutan','Tamarind']
fruits_Hard = ['Blackberry','Blueberry','Boysenberry','Breadfruit','Cantaloupe','Cherimoya','Clementine','Cranberry','Dragonfruit','Elderberry','Gooseberry','Grapefruit','Jackfruit','Mangosteen','Nectarine','Passionfruit','Persimmon','Pineapple','Pomegranate','Raspberry','Redcurrant','Starfruit','Strawberry','Tangerine','Watermelon']
cars_easy = ['Ford','BMW','Audi','Jeep','Kia','Mini','Fiat','Volvo','Saab','Tesla','Skoda','Opel','Dacia','Lexus','Honda','Mazda',
 'Chevy','Buick','Ram','Zotye','Isuzu','Acura','BYD','Tata','JAC','Scion','Seat','Smart','Roewe','Lucid']
cars_medium=['Nissan','Hyundai','Subaru','Suzuki','Toyota','Bugatti','Peugeot','Renault','Daihatsu','Infiniti','Citroen','Pontiac','Rivian','Pagani','Proton','Saturn',
 'Genesis','Holden','Perodua','Fisker','Polestar','VinFast','Daewoo']
cars_hard=['Brilliance', 'Koenigsegg', 'SsangYong']


def hangman(level_list:list):
    #print(level_list)
    if level_list=='11':
        level_list=fruits_easy
        typee='Fruit'
    elif level_list=='12':
        level_list=fruits_medium
        typee='Fruit'
    elif level_list=='13':
        level_list=fruits_Hard
        typee='Fruit'
    elif level_list=='21':
        level_list=cars_easy
        typee='Car'
    elif level_list=='22':
        level_list=cars_medium
        typee='Car'
    elif level_list=='23':
        level_list=cars_hard
        typee='Car'
    #else:
     #   print('Choos Only From the List!!')
      #  hangman(input('Choose Game Category ---> 1.fruits,2.cars')+input('Choose Game Level ---> 1.easy ,2.medium ,3.hard '))
        
    import random

    Computer_choice=random.choice(level_list).lower()
    player_list=list(Computer_choice)
    player_list_empty=list(Computer_choice)
    for indx in range(len(player_list_empty)):
        player_list_empty[indx]='_'

        
    print(player_list_empty)
    count_trials=len(Computer_choice)+2


    while True:    
        if count_trials>=1:
            player_choice=input('Guess Charecter :.....   Type--> 0 To Exit The Game')
            if player_choice in player_list_empty :
                print(f'You Already Entered {player_choice} before')
            else:
                print(player_choice)
                count_trials-=1
                if (player_choice in Computer_choice) or (player_choice.lower()==Computer_choice.lower()) or (player_choice=='0'.lower()):

                    if player_choice=='0':
                        print('Game Ended by Player!!')
                        break
                    elif player_choice.lower()==Computer_choice.lower():
                        print('Congratulation!!')
                        print(f'{typee} is {Computer_choice}')
                        print('You Win')
                        break
                    else:

                        Computer_choice.count(player_choice)
                        for i in range(len(Computer_choice)):

                            if Computer_choice[i]==player_choice:
                                player_list_empty[i]=player_choice
                        print(f'Corrct {Computer_choice.count(player_choice)} Characters Found')
                        print(player_list_empty)
                        print(''.join(player_list_empty))
                        print(count_trials, 'left')
                        if player_list==player_list_empty:
                            print('Congratulation!!')
                            print(f'{typee}  is {Computer_choice}')
                            print('You Win')
                            break
                    
                    

                else:
                    print(f'OOPS....Try Harder {count_trials} trials Left')
                    print(player_list_empty)
                    print(' '.join(player_list_empty))
                    #print(count_trials, 'left')
        else:
            
            if player_list==player_list_empty:
                print('Congratulation!!')
                print(f'{typee}  is {Computer_choice}')
                print('You Win')
                break
                
            else:
                
                last_chance=input('Last Chance....Try To Geuss!').lower()
                if last_chance.lower()==Computer_choice.lower():
                    print('Congratulation!!')
                    print(f'{typee}  is {Computer_choice}')
                    print('You Win in the last Chance!')
                    break
                else:
                    print('Game Over')
                    print(f'{typee}  is {Computer_choice}')
                    print('You Loose!!')
            break

def hangman_game():
    print('Categories :\n1- Fruits\n2- Cars')
    print('Level :\n1- Easy\n2- Medium\n3- Hard')
    hangman(input('Choose Game Category ---> 1.fruits,2.cars')+input('Choose Game Level ---> 1.easy ,2.medium ,3.hard '))

# %%
hangman_game()
# Out:
# Categories :
# 1- Fruits
# 2- Cars
# Level :
# 1- Easy
# 2- Medium
# 3- Hard
# ['_', '_', '_']
# b
# Corrct 1 Characters Found
# ['b', '_', '_']
# b__
# 4 left
# y
# OOPS....Try Harder 3 trials Left
# ['b', '_', '_']
# b _ _
# a
# OOPS....Try Harder 2 trials Left
# ['b', '_', '_']
# b _ _
# BMW
# Congratulation!!
# Car is bmw
# You Win
